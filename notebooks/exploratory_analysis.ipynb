# %% [markdown]
# # Exploratory analysis
#
# Use este notebook para investigar historico de precos, variacoes e comparativos de CMV a partir de `data/database/prices.db`.

# %%
import sqlite3
from pathlib import Path

import pandas as pd

db_path = Path('data/database/prices.db')
conn = sqlite3.connect(db_path)
observations = pd.read_sql('SELECT * FROM price_observations', conn)
observations.head()
